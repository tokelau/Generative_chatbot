# %%
st = """100	2.872600
200	2.336500
300	2.309400
400	2.312500
500	2.293500
600	2.209000
700	2.251700
800	2.262800
900	2.272700
1000	2.218400
1100	2.208200
1200	2.241900
1300	2.229500
1400	2.231900
1500	2.184500
1600	2.182800
1700	2.168800
1800	2.168200
1900	2.171500
2000	2.151800
2100	2.146700
2200	2.167900
2300	2.143500
2400	2.155200
2500	2.143800
2600	2.165500
2700	2.118600
2800	2.160300
2900	2.134300
3000	2.142200
3100	2.187900
3200	2.143700
3300	2.087100
3400	2.104100
3500	2.119100
3600	2.079500
3700	2.101800
3800	2.124400
3900	2.079800
4000	2.092100
4100	2.121300
4200	2.057100
4300	2.096700
4400	2.119300
4500	2.098400
4600	2.123100"""

# %%
lst = [item.split('\t') for item in st.split('\n')]

# %%
import pandas as pd
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.DataFrame.from_records(lst, columns=["step", "score"])
df['score'] = df['score'].astype(float)

# %%
df.iloc[::2].plot(kind="line", x='step', y='score', title='Training score by step')
# Out:
# <Axes: title={'center': 'Training score by step'}, xlabel='step'>
